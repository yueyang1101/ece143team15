# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import pandas as pd
import seaborn as sns
from pyecharts import TreeMap

# %%
df=pd.read_csv("co2concentration-temperature.csv")
####################################################

sns.set(style="white")
fig, ax=plt.subplots()
fig.set_size_inches(15, 10)
ax2=ax.twinx()
sns.set(color_codes=True)
#sns.color_palette("husl", 8)
cmap = sns.cubehelix_palette(dark=.0, light=.8, as_cmap=True)
#sns.despine(top= True, right=False)
#sns.scatterplot(x="year", y="co2 concentration", data=df, ax=ax, color="pink", size="size1", legend=False)
#sns.scatterplot(x="year", y="temperature anomaly", data=df, ax=ax2, color="c", size="size2", legend=False)
sns.regplot(x="year", y="co2 concentration", data=df, ax=ax, order=2, color="pink", marker="o", label="co2 concentration")
sns.regplot(x="year", y="temperature anomaly", data=df, ax=ax2, order=2, color="c", marker="o", label="temperature anomaly")
fig.legend(loc=2, bbox_to_anchor=(0.065, 0.8))
a=ax2.set_ylim(-1,1)
#sns.lmplot(x="year", y="co2 concentration", hue="temperature anomaly", data=df)

# %%
df=pd.read_csv("co2emission-temperature.csv")
####################################################

sns.set(style="white")
fig, ax=plt.subplots()
fig.set_size_inches(15, 10)
ax2=ax.twinx()
sns.set(color_codes=True)
cmap = sns.cubehelix_palette(dark=.0, light=.8, as_cmap=True)
sns.regplot(x="year", y="global co2 emission", data=df2, ax=ax, order=2, color="pink", marker="o", label="global co2 emission")
sns.regplot(x="year", y="temperature anomaly", data=df2, ax=ax2, order=2, color="c", marker="o", label="temperature anomaly")
fig.legend(loc=2, bbox_to_anchor=(0.065, 0.8))
a=ax2.set_ylim(-1,1)

# %%
f=open("wordcloud.txt").read()

earthfig=np.array(Image.open("Equal_Earth_projection_SW2.jpg"))
stopwords = set(STOPWORDS)
stopwords.add("said")

wordcloud = WordCloud(background_color="white", mask=earthfig, stopwords=stopwords, collocations=False).generate(f)

fig, axes = plt.subplots(3, 1)
fig.set_size_inches(55, 50)
axes[0].imshow(wordcloud, interpolation="bilinear")
image_colors = ImageColorGenerator(earthfig)
# recolor wordcloud and show
# we could also give color_func=image_colors directly in the constructor
axes[1].imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear")
axes[2].imshow(earthfig, cmap=plt.cm.gray, interpolation="bilinear")
for ax in axes:
    ax.set_axis_off()
plt.show()

# %%
f=open("tree.txt",'r')
a=f.read()
tree=eval(a)
f.close()
############################################################

counter=0
for i in range(len(tree)):
    counter+=tree[i]["value"]

for i in range(len(tree)):
    tree[i]["value"]=tree[i]["value"]/counter

# change the ratio from region to global
for i in tree:
    for j in i["children"]:
        j["value"]=j["value"]*i["value"]
bcounter=round(counter/pow(10,9))
def label(params):
    return params.name+"\n"+window.parseFloat(params.value*100).toFixed(2)+r"%"+" "+"co2 emission" 

treemap=TreeMap(width=800, height=800, title_text_size=24, is_animation=True, renderer="canvas")
treemap.add("Co2 emission in 10 years", tree, is_random=False, is_legend_show=True
           , line_opacity=0.5
           , is_label_show=True
           , label_pos="inside"
           , legend_orient="vertical"
           , label_formatter=label
           , is_more_utils=True
           , label_text_size =24)
#treemap.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5ede0ecc67a045989a4c8553ac6fafc9" style="width:800px;height:800px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5ede0ecc67a045989a4c8553ac6fafc9 = echarts.init(document.getElementById('5ede0ecc67a045989a4c8553ac6fafc9'), 'light', {renderer: 'canvas'});
# function label(params) {
#     return ((((params.name + "\n") + window.parseFloat((params.value * 100)).toFixed(2)) + "%") + "  co2 emission");
# }
#
# var option_5ede0ecc67a045989a4c8553ac6fafc9 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 24
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 8268418,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "treemap",
#             "name": "Co2 emission in 10 years",
#             "data": [
#                 {
#                     "value": 0.03731248983940441,
#                     "name": "AFRICA",
#                     "children": [
#                         {
#                             "name": "Algeria",
#                             "value": 0.003950646419289638
#                         },
#                         {
#                             "name": "Angola",
#                             "value": 0.0009480919965522639
#                         },
#                         {
#                             "name": "Benin",
#                             "value": 0.00016469300572532827
#                         },
#                         {
#                             "name": "Botswana",
#                             "value": 0.00016001315707345784
#                         },
#                         {
#                             "name": "Burkina Faso",
#                             "value": 7.254326494256123e-05
#                         },
#                         {
#                             "name": "Burundi",
#                             "value": 9.217109067480084e-06
#                         },
#                         {
#                             "name": "Cameroon",
#                             "value": 0.00019835569768120103
#                         },
#                         {
#                             "name": "Cape Verde",
#                             "value": 1.6036114215817255e-05
#                         },
#                         {
#                             "name": "Central African Republic",
#                             "value": 8.659150742016124e-06
#                         },
#                         {
#                             "name": "Chad",
#                             "value": 1.834367337414912e-05
#                         },
#                         {
#                             "name": "Comoros",
#                             "value": 4.504821107648526e-06
#                         },
#                         {
#                             "name": "Djibouti",
#                             "value": 1.7689735663834744e-05
#                         },
#                         {
#                             "name": "Egypt",
#                             "value": 0.006243771023136389
#                         },
#                         {
#                             "name": "Equatorial Guinea",
#                             "value": 0.00016239697591736174
#                         },
#                         {
#                             "name": "Ethiopia",
#                             "value": 0.00026867474086982447
#                         },
#                         {
#                             "name": "Gabon",
#                             "value": 0.00014952542613972595
#                         },
#                         {
#                             "name": "Ghana",
#                             "value": 0.00035422350335712017
#                         },
#                         {
#                             "name": "Guinea",
#                             "value": 7.372690970547878e-05
#                         },
#                         {
#                             "name": "Kenya",
#                             "value": 0.00038356403549020586
#                         },
#                         {
#                             "name": "Lesotho",
#                             "value": 7.182637216043749e-05
#                         },
#                         {
#                             "name": "Liberia",
#                             "value": 2.5020063093196755e-05
#                         },
#                         {
#                             "name": "Libya",
#                             "value": 0.0016386096948272067
#                         },
#                         {
#                             "name": "Madagascar",
#                             "value": 7.582253414451889e-05
#                         },
#                         {
#                             "name": "Malawi",
#                             "value": 3.448208930772003e-05
#                         },
#                         {
#                             "name": "Mali",
#                             "value": 3.481259591110888e-05
#                         },
#                         {
#                             "name": "Mauritania",
#                             "value": 6.571050018336956e-05
#                         },
#                         {
#                             "name": "Mauritius",
#                             "value": 0.00012190606009858446
#                         },
#                         {
#                             "name": "Morocco",
#                             "value": 0.0017681541117750225
#                         },
#                         {
#                             "name": "Mozambique",
#                             "value": 0.000143469518865547
#                         },
#                         {
#                             "name": "Namibia",
#                             "value": 9.943985191398586e-05
#                         },
#                         {
#                             "name": "Niger",
#                             "value": 4.693911667169252e-05
#                         },
#                         {
#                             "name": "Nigeria",
#                             "value": 0.0029054054962436558
#                         },
#                         {
#                             "name": "Rwanda",
#                             "value": 2.194971006086661e-05
#                         },
#                         {
#                             "n
